# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# %matplotlib inline 
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#sns.pairplot(df)

# %%
dd = df.describe()
dd
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#sns.pairplot(dd)

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
# Avec le code ci dessous je remplace les valeurs Nan
for name in df.columns:
    x = df[name].isna().sum()
    if x > 0:
        val_list = np.random.choice(df.groupby(name).count().index, x, p=df.groupby(name).count()['Id'].values /sum(df.groupby(name).count()['Id'].values))
        df.loc[df[name].isna(), name] = val_list

# %%
#df.info()

# %%
sum(df.isna().sum())
# Out:
# 0

# %%
df.MasVnrArea.mean()
# Out:
# 104.5

# %%
df['MasVnrArea'] = df['MasVnrArea'].replace(0.0,df['MasVnrArea'].mean())

# %%
df.MasVnrArea
# Out:
# 0       196.0
# 1       104.5
# 2       162.0
# 3       104.5
# 4       350.0
#         ...
# 1455    104.5
# 1456    119.0
# 1457    104.5
# 1458    104.5
# 1459    104.5
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
df2 = df[['SalePrice', 'OverallQual', 'YearRemodAdd', 'MasVnrArea']]

# %%
df2
# Out:
#       SalePrice  OverallQual  YearRemodAdd  MasVnrArea
# 0        208500            7          2003       196.0
# 1        181500            6          1976       104.5
# 2        223500            7          2002       162.0
# 3        140000            7          1970       104.5
# 4        250000            8          2000       350.0
# ...         ...          ...           ...         ...
# 1455     175000            6          2000       104.5
# 1456     210000            6          1988       119.0
# 1457     266500            7          2006       104.5
# 1458     142125            5          1996       104.5
# 1459     147500            5          1965       104.5
#
# [1460 rows x 4 columns]

# %%
df2.isnull().sum()
# Out:
# SalePrice       0
# OverallQual     0
# YearRemodAdd    0
# MasVnrArea      0
# dtype: int64

# %% [markdown]
# ## Linear Regression Univariate

# %%
corr_matrix = df2.corr()
sns.heatmap(corr_matrix, square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(data=df2, x='OverallQual', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# ### Problématique
# #### On souhaiterait prédire le SalePrice en fonction de la OverallQual.

# %%
lm1 = sm.ols(formula='SalePrice ~ OverallQual', data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-312-2f83a5aee1c0> in <module>
# ----> 1 lm1 = sm.ols(formula='SalePrice ~ OverallQual', data=df).fit()
#
# AttributeError: module 'statsmodels.api' has no attribute 'ols'

# %%
lm1.summary()

# %% [markdown]
# #### R-squared = 0.626
# * 62.6 % de la variation de la variable Y (SalePrice) est expliquée par la variable X (OverallQual).
# * notre modèle est capable de déterminer la distribution à 62.6 %
#
# #### coef = 4.544e+04
# * Le signe d'un coefficient de régression vous indique s'il existe une corrélation positive ou négative entre chaque variable indépendante et la variable dépendante.

# %%
# result = lm1.params['OverallQual']*7 + lm1.params['Intercept']
# result
X = sm.add_constant(x)

# %% [markdown]
# ### Prediction avec Sklearn (univariate)

# %%
reg = linear_model.LinearRegression()
reg.fit(df2[['OverallQual']],df.SalePrice)

# %%
reg.coef_

# %%
reg.intercept_

# %% [markdown]
# #### Predicte the price of a home with 8 OverallQualification

# %%
reg.predict([[8]])

# %% [markdown]
# ## Linear Regression Multivariate

# %% [markdown]
# y = m1x1 + m2x2 + m3x3 + b

# %%
sns.pairplot(df2)

# %%
lm2 = smf.ols(formula='SalePrice ~ OverallQual + YearRemodAdd + YearRemodAdd', data=df).fit()

# %%
lm2.summary()

# %%
 lm2.predict(res.params[['OverallQual','YearRemodAdd','MasVnrArea']] + lm2.params['Intercept']
result2

# %% [markdown]
# ### Prediction avec Sklearn

# %%
from sklearn.linear_model import LinearRegression
X = df2[['OverallQual','YearRemodAdd','MasVnrArea']]
y = df2.SalePrice
reg = LinearRegression().fit(X,y)
reg.score(X,y)
#reg.fit(df2[['OverallQual','YearRemodAdd','MasVnrArea']],df2.SalePrice)

# %%
reg.coef_

# %%
reg.intercept_

# %% [markdown]
# #### Predicte the price of a home with 6 OverallQualification, Remodeled year 1976 with 103 sqr metre

# %%
reg.predict([[6, 1976, 103]])
